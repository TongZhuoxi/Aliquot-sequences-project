# %% [markdown]
# # Table Of Contents #
#
# **Core Questions**
#
# $\triangleright $ **Question One** - creating a function to calculate the sum of proper divisors.
#
# $\triangleright $ **Question Two** - creating a function to form the aliquot sequences.
#
# $\triangleright $ **Question Three** - developing code that can identify whether a sequence loops.
#
# $\triangleright $ **Question Four** - classifying aliquot sequnces.
#
# $\triangleright $ **Question Five** - experimenting with parameters.
#
# **Extension Questions**
#
# $\triangleright $ **Question Seven** - researching and visualising how sequences that enter loops.
#
# $\triangleright $ **Question Eight** - investigating the properties of abundant and deficient numbers.
